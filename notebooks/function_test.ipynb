# %%
import sys
from pathlib import Path

source_dir = Path('..').resolve()
if source_dir not in sys.path:
    sys.path.append(str(source_dir))

# %%
from main2 import tth2q_wavelen

wavelen: float = 1.54

print(tth2q_wavelen(1))
print(tth2q_wavelen(2))
# Out:
# 0.07120836315060285
# 0.14241130350865738
