# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np

from reflecto.physics_utils import tth2q
from reflecto.simulate.simulator import ParamSet, build_structure, compute_refl

wavelen: float = 1.54  # (nm)
tth_min: float = 0.1   # degree
tth_max: float = 6.0
q_n: int = 200
tths: np.ndarray = np.linspace(tth_min, tth_max, q_n)
q_min: float = tth2q(tth_min, wavelen)  # (1/Å)
q_max: float = tth2q(tth_max, wavelen)
qs: np.ndarray = np.linspace(q_min, q_max, q_n)

n_layers: int = 2

# %%
import matplotlib.pyplot as plt
from reflecto.simulator.simulator import XRRSimulator

params = [ParamSet(42, 1, 5), ParamSet(50, 2, 40)]
stack = build_structure(params)
refl = compute_refl(stack, qs, is_footprint=False)
refl2 = compute_refl(stack, qs, is_footprint=True)
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
ax.plot(qs, refl)
ax.plot(qs, refl2)
ax.set_yscale('log')

plt.show()

# %%
xrr_sim = XRRSimulator(qs, 2, 1)
films, sio2, refl = next(xrr_sim.generate_batch())
thicknesses = [f.thickness for f in films]
roughnesses = [f.roughness for f in films]
slds = [f.sld for f in films]())
fig, ax = plt.subplots(1, 1, figsize=(8, 5))
ax.plot(qs, refl)
ax.set_yscale('log')
